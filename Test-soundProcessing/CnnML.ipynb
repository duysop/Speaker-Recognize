# %%
import tensorflow as tf
from tensorflow import keras
from json import loads
import pandas as pd
from keras import datasets, layers, models
from sklearn.model_selection import train_test_split
import numpy as np
from ast import literal_eval
import pickle

# %%
with open('../Data/LibriSpeech/my_dict.pkl', 'rb') as f:
    my_dict = pickle.load(f)
my_dict
x=[]
y=[]
for i in my_dict:
    x.append(i['speaker'])
    y.append(i['cepstrum'])
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
# create an example list of labels
labels = x
# create a LabelEncoder object
le = LabelEncoder()
# fit the encoder to the labels and transform the labels
x = le.fit_transform(labels)
print(len(le.classes_))
# print the original labels and the encoded labels
print("Original labels:", labels)
print("Encoded labels:", x)

y=np.array(y)
y.shape

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, stratify=x, random_state=42)
# Out:
# 26
# Original labels: [' Karen Savage', ' Karen Savage', ' Karen Savage', ' Karen Savage', ' Karen Savage', ' Karen Savage', ' Karen Savage', ' Karen Savage', ' Karen Savage', ' Karen Savage', ' Karen Savage', ' Karen Savage', ' Karen Savage', ' Karen Savage', ' Karen Savage', ' Karen Savage', ' Karen Savage', ' Karen Savage', ' Karen Savage', ' Karen Savage', ' Karen Savage', ' Karen Savage', ' Karen Savage', ' Karen Savage', ' Karen Savage', ' Karen Savage', ' Karen Savage', ' Karen Savage', ' Karen Savage', ' Karen Savage', ' Karen Savage', ' Karen Savage', ' Karen Savage', ' Karen Savage', ' Karen Savage', ' Karen Savage', ' Karen Savage', ' Karen Savage', ' Karen Savage', ' Karen Savage', ' Karen Savage', ' Karen Savage', ' Karen Savage', ' Karen Savage', ' Karen Savage', ' Karen Savage', ' Karen Savage', ' Karen Savage', ' Karen Savage', ' Karen Savage', ' Karen Savage', ' Karen Savage', ' Karen Savage', ' Karen Savage', ' Karen Savage', ' Karen Savage', ' Karen Savage', ' Karen Savage', ' Karen Savage', ' Karen Savage', ' Karen Savage', ' Karen Savage', ' Karen Savage', ' Karen Savage', ' Karen Savage', ' Karen Savage', ' Karen Savage', ' Karen Savage', ' Karen Savage', ' Karen Savage', ' Karen Savage', ' Karen Savage', ' Karen Savage', ' Karen Savage', ' Karen Savage', ' Karen Savage', ' Karen Savage', ' Karen Savage', ' Karen Savage', ' Karen Savage', ' Karen Savage', ' Karen Savage', ' Karen Savage', ' Karen Savage', ' Karen Savage', ' Karen Savage', ' Karen Savage', ' Karen Savage', ' Karen Savage', ' Karen Savage', ' Karen Savage', ' Karen Savage', ' Karen Savage', ' Karen Savage', ' Karen Savage', ' Karen Savage', ' Karen Savage', ' Karen Savage', ' Karen Savage', ' Karen Savage', ' Karen Savage', ' Karen Savage', " Kevin O'Coin", " Kevin O'Coin", " Kevin O'Coin", " Kevin O'Coin", " Kevin O'Coin", " Kevin O'Coin", " Kevin O'Coin", " Kevin O'Coin", " Kevin O'Coin", " Kevin O'Coin", " Kevin O'Coin", " Kevin O'Coin", " Kevin O'Coin", " Kevin O'Coin", " Kevin O'Coin", " Kevin O'Coin", " Kevin O'Coin", " Kevin O'Coin", " Kevin O'Coin", " Kevin O'Coin", " Kevin O'Coin", " Kevin O'Coin", " Kevin O'Coin", " Kevin O'Coin", " Kevin O'Coin", " Kevin O'Coin", " Kevin O'Coin", " Kevin O'Coin", " Kevin O'Coin", " Kevin O'Coin", " Kevin O'Coin", " Kevin O'Coin", " Kevin O'Coin", " Kevin O'Coin", " Kevin O'Coin", " Kevin O'Coin", " Kevin O'Coin", " Kevin O'Coin", " Kevin O'Coin", " Kevin O'Coin", " Kevin O'Coin", " Kevin O'Coin", " Kevin O'Coin", " Kevin O'Coin", " Kevin O'Coin", " Kevin O'Coin", " Kevin O'Coin", " Kevin O'Coin", " Kevin O'Coin", " Kevin O'Coin", " Kevin O'Coin", " Kevin O'Coin", " Kevin O'Coin", " Kevin O'Coin", " Kevin O'Coin", " Kevin O'Coin", " Kevin O'Coin", " Kevin O'Coin", " Kevin O'Coin", " Kevin O'Coin", " Kevin O'Coin", " Kevin O'Coin", " Kevin O'Coin", " Kevin O'Coin", " Kevin O'Coin", " Kevin O'Coin", " Kevin O'Coin", " Kevin O'Coin", " Kevin O'Coin", " Kevin O'Coin", " Kevin O'Coin", " Kevin O'Coin", " Kevin O'Coin", " Kevin O'Coin", " Kevin O'Coin", " Kevin O'Coin", " Kevin O'Coin", " Kevin O'Coin", " Kevin O'Coin", " Kevin O'Coin", " Kevin O'Coin", " Kevin O'Coin", " Kevin O'Coin", " Kevin O'Coin", " Kevin O'Coin", " Kevin O'Coin", " Kevin O'Coin", " Kevin O'Coin", " Kevin O'Coin", " Kevin O'Coin", " Kevin O'Coin", " Kevin O'Coin", " Kevin O'Coin", " Kevin O'Coin", " Kevin O'Coin", " Kevin O'Coin", ' John Garvin', ' John Garvin', ' John Garvin', ' John Garvin', ' John Garvin', ' John Garvin', ' John Garvin', ' John Garvin', ' John Garvin', ' John Garvin', ' John Garvin', ' John Garvin', ' John Garvin', ' John Garvin', ' John Garvin', ' John Garvin', ' John Garvin', ' John Garvin', ' John Garvin', ' John Garvin', ' John Garvin', ' John Garvin', ' John Garvin', ' John Garvin', ' John Garvin', ' John Garvin', ' John Garvin', ' John Garvin', ' John Garvin', ' John Garvin', ' John Garvin', ' John Garvin', ' John Garvin', ' John Garvin', ' John Garvin', ' John Garvin', ' John Garvin', ' John Garvin', ' John G ...
# Encoded labels: [13 13 13 ...  1  1  1]

# %%
print("Class distribution in training set:", np.bincount(x))
# Out:
# Class distribution in training set: [137  51 136  98 112 138 101 108 114 130  81 107 129 102  96 109 118 129
#  126  92 102 117  98 125  66 131]

# %%
timestep=y.shape[1]
feature=y.shape[2]
model=models.Sequential()
model.add(keras.layers.Input(shape=(timestep,feature)))
model.add(keras.layers.Conv1D(filters=64, kernel_size=5,activation='relu', name="Conv1D_1"))
model.add(keras.layers.Dropout(0.1))
model.add(keras.layers.Conv1D(filters=32, kernel_size=4, activation='relu', name="Conv1D_2"))
  
model.add(keras.layers.Conv1D(filters=16, kernel_size=2, activation='relu', name="Conv1D_3"))
  
model.add(keras.layers.MaxPooling1D(pool_size=2, name="MaxPooling1D"))
model.add(keras.layers.Flatten())
model.add(keras.layers.Dense(64, activation='relu', name="Dense_1"))
model.add(keras.layers.Dense(len(le.classes_), name="Dense_2"))
model.add(keras.layers.Activation('softmax'))
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Conv1D_1 (Conv1D)           (None, 19, 64)            30784
#
#  dropout_1 (Dropout)         (None, 19, 64)            0
#
#  Conv1D_2 (Conv1D)           (None, 11, 32)            18464
#
#  Conv1D_3 (Conv1D)           (None, 4, 16)             4112
#
#  MaxPooling1D (MaxPooling1D)  (None, 2, 16)            0
#
#  flatten_1 (Flatten)         (None, 32)                0
#
#  Dense_1 (Dense)             (None, 64)                2112
#
#  Dense_2 (Dense)             (None, 26)                1690
#
#  activation_1 (Activation)   (None, 26)                0
#
# =================================================================
# Total params: 57,162
# Trainable params: 57,162
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy( from_logits=False),
              metrics=['accuracy'])
history=model.fit(y_train,x_train,batch_size=4,epochs=100,validation_data=(y_test,x_test))
# Out:
# Epoch 1/100
# 571/571 [==============================] - 5s 7ms/step - loss: 3.3386 - accuracy: 0.0403 - val_loss: 3.2491 - val_accuracy: 0.0473
# Epoch 2/100
# 571/571 [==============================] - 4s 6ms/step - loss: 3.2479 - accuracy: 0.0460 - val_loss: 3.2428 - val_accuracy: 0.0473
# Epoch 3/100
# 571/571 [==============================] - 4s 7ms/step - loss: 3.2436 - accuracy: 0.0478 - val_loss: 3.2395 - val_accuracy: 0.0473
# Epoch 4/100
# 571/571 [==============================] - 4s 7ms/step - loss: 3.2417 - accuracy: 0.0434 - val_loss: 3.2379 - val_accuracy: 0.0473
# Epoch 5/100
# 571/571 [==============================] - 4s 8ms/step - loss: 3.2411 - accuracy: 0.0469 - val_loss: 3.2373 - val_accuracy: 0.0473
# Epoch 6/100
# 571/571 [==============================] - 4s 7ms/step - loss: 3.2408 - accuracy: 0.0473 - val_loss: 3.2371 - val_accuracy: 0.0473
# Epoch 7/100
# 571/571 [==============================] - 3s 6ms/step - loss: 3.2404 - accuracy: 0.0451 - val_loss: 3.2370 - val_accuracy: 0.0473
# Epoch 8/100
# 571/571 [==============================] - 4s 7ms/step - loss: 3.2409 - accuracy: 0.0421 - val_loss: 3.2369 - val_accuracy: 0.0490
# Epoch 9/100
# 571/571 [==============================] - 4s 7ms/step - loss: 3.2408 - accuracy: 0.0451 - val_loss: 3.2370 - val_accuracy: 0.0490
# Epoch 10/100
# 571/571 [==============================] - 3s 6ms/step - loss: 3.2405 - accuracy: 0.0394 - val_loss: 3.2369 - val_accuracy: 0.0490
# Epoch 11/100
# 571/571 [==============================] - 3s 6ms/step - loss: 3.2406 - accuracy: 0.0447 - val_loss: 3.2369 - val_accuracy: 0.0490
# Epoch 12/100
# 571/571 [==============================] - 4s 6ms/step - loss: 3.2406 - accuracy: 0.0421 - val_loss: 3.2369 - val_accuracy: 0.0490
# Epoch 13/100
# 571/571 [==============================] - 3s 6ms/step - loss: 3.2403 - accuracy: 0.0412 - val_loss: 3.2368 - val_accuracy: 0.0490
# Epoch 14/100
# 571/571 [==============================] - 4s 7ms/step - loss: 3.2405 - accuracy: 0.0447 - val_loss: 3.2368 - val_accuracy: 0.0490
# Epoch 15/100
# 571/571 [==============================] - 3s 6ms/step - loss: 3.2403 - accuracy: 0.0456 - val_loss: 3.2369 - val_accuracy: 0.0490
# Epoch 16/100
# 571/571 [==============================] - 4s 7ms/step - loss: 3.2401 - accuracy: 0.0473 - val_loss: 3.2369 - val_accuracy: 0.0490
# Epoch 17/100
# 571/571 [==============================] - 4s 8ms/step - loss: 3.2400 - accuracy: 0.0451 - val_loss: 3.2368 - val_accuracy: 0.0490
# Epoch 18/100
# 570/571 [============================>.] - ETA: 0s - loss: 3.2404 - accuracy: 0.0439
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 4
#       1 model.compile(optimizer='adam',
#       2               loss=tf.keras.losses.SparseCategoricalCrossentropy( from_logits=False),
#       3               metrics=['accuracy'])
# ----> 4 history=model.fit(y_train,x_train,batch_size=4,epochs=100,validation_data=(y_test,x_test))
#
# File c:\Users\Admin\miniconda3\envs\abcd\lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\Admin\miniconda3\envs\abcd\lib\site-packages\keras\engine\training.py:1606, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1591 if getattr(self, "_eval_data_handler", None) is None:
#    1592     self._eval_data_handler = data_adapter.get_data_handler(
#    1593         x=val_x,
#    1594         y=val_y,
#    (...)
#    1604         steps_per_execution=self._steps_per_execution,
#    1605     )
# -> 1606 val_logs = self.evaluate(
#    1607     x=val_x,
#    1608     y=val_y,
#    1609     sample_weight=val_sample_weight,
#    1610     batch_size=validation_batch_size or batch_size,
#    1611     steps=validation_steps,
#    1612     callbacks=callbacks,
#    1613     max_queue_size=max_queue_size,
#    1614     workers=workers,
#    1615     use_multiprocessing=use_multiprocessing,
#    1616     return_dict=True,
#    1617     _use_cached_eval_dataset=True,
#    1618 )
#    1619 val_logs = {
#    1620     "val_" + name: val for name, val in val_logs.items()
#    1621 }
#    1622 epoch_logs.update(val_logs)
#
# File c:\Users\Admin\miniconda3\envs\abcd\lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\Admin\miniconda3\envs\abcd\lib\site-packages\keras\engine\training.py:1939, in Model.evaluate(self, x, y, batch_size, verbose, sample_weight, steps, callbacks, max_queue_size, workers, use_multiprocessing, return_dict, **kwargs)
#    1937 self._test_counter.assign(0)
#    1938 callbacks.on_test_begin()
# -> 1939 for _, iterator in data_handler.enumerate_epochs():  # Single epoch.
#    1940     self.reset_metrics()
#    1941     with data_handler.catch_stop_iteration():
#
# File c:\Users\Admin\miniconda3\envs\abcd\lib\site-packages\keras\engine\data_adapter.py:1307, in DataHandler.enumerate_epochs(self)
#    1305 """Yields `(epoch, tf.data.Iterator)`."""
#    1306 with self._truncate_execution_to_epoch():
# -> 1307     data_iterator = iter(self._dataset)
#    1308     for epoch in range(self._initial_epoch, self._epochs):
#    1309         if self._insufficient_data:  # Set by `catch_stop_iteration`.
#
# File c:\Users\Admin\miniconda3\envs\abcd\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py:499, in DatasetV2.__iter__(self)
#     497 if context.executing_eagerly() or ops.inside_function():
#     498   with ops.colocate_with(self._variant_tensor):
# --> 499     return iterator_ops.OwnedIterator(self)
#     500 else:
#     501   raise RuntimeError("`tf.data.Dataset` only supports Python-style "
#     502                      "iteration in eager mode or within tf.function.")
#
# File c:\Users\Admin\miniconda3\envs\abcd\lib\site-packages\tensorflow\python\data\ops\iterator_ops.py:696, in OwnedIterator.__init__(self, dataset, components, element_spec)
#     692   if (components is not None or element_spec is not None):
#     693     raise ValueError(
#     694         "When `dataset` is provided, `element_spec` and `components` must "
#     695         "not be specified.")
# --> 696   self._create_iterator(dataset)
#     698 self._get_next_call_count = 0
#
# File c:\Users\Admin\miniconda3\envs\abcd\lib\site-packages\tensorflow\python\data\ops\iterator_ops.py:721, in OwnedIterator._create_iterator(self, dataset)
#     716 with ops.colocate_with(ds_variant):
#     717   self._iterator_resource = (
#     718       gen_dataset_ops.anonymous_iterator_v3(
#     719           output_types=self._flat_output_types,
#     720           output_shapes=self._flat_output_shapes))
# --> 721   gen_dataset_ops.make_iterator(ds_variant, self._iterator_resource)
#
# File c:\Users\Admin\miniconda3\envs\abcd\lib\site-packages\tensorflow\python\ops\gen_dataset_ops.py:3408, in make_iterator(dataset, iterator, name)
#    3406 if tld.is_eager:
#    3407   try:
# -> 3408     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    3409       _ctx, "MakeIterator", name, dataset, iterator)
#    3410     return _result
#    3411   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
y
# Out:
# array([[[ -29.03917085,   30.56884854,  -13.02667388, ...,
#             0.949094  ,  -13.02667388,   30.56884854],
#         [  -5.96969316,   13.51925726,  -20.35159542, ...,
#            14.51571127,  -20.35159542,   13.51925726],
#         [ -81.46962228,   22.26520001,   21.88589023, ...,
#             5.53885374,   21.88589023,   22.26520001],
#         ...,
#         [  10.44872623,   -1.93174453,   -9.03003706, ...,
#           -15.89730216,   -9.03003706,   -1.93174453],
#         [  -9.4579219 ,   18.46066568,   -3.78728616, ...,
#           -12.39175529,   -3.78728616,   18.46066568],
#         [ -64.18635561,    5.53146892,   16.55220081, ...,
#             6.42650633,   16.55220081,    5.53146892]],
#
#        [[ -30.4585925 ,   37.97484866,   -8.45721079, ...,
#            -2.06619904,   -8.45721079,   37.97484866],
#         [  -1.58843309,    5.28527762,   -4.40592502, ...,
#           -10.81479877,   -4.40592502,    5.28527762],
#         [ -77.05899032,   16.67127756,   15.515678  , ...,
#             6.10267793,   15.515678  ,   16.67127756],
#         ...,
#         [ -19.88874565,   11.41687926,   -3.53802994, ...,
#           -14.68897048,   -3.53802994,   11.41687926],
#         [  -9.72896894,    8.43440775,   -1.94434011, ...,
